# %%
import numpy as np
from PIL import Image
import cv2

# %%
from ISR.models import RDN

rdn = RDN(arch_params={'C':6, 'D':20, 'G':64, 'G0':64, 'x':2})
rdn.model.load_weights('weights/sample_weights/rdn-C6-D20-G64-G064-x2/ArtefactCancelling/rdn-C6-D20-G64-G064-x2_ArtefactCancelling_epoch219.hdf5')

# %%
img = Image.open('data/input/sample/baboon.png')
lr_img = np.array(img)
print('size: ', img.size)
print('type: ', type(img))
print('lr_shape: ',lr_img.shape)
print('type: ', type(lr_img))
# Out:
# size:  (125, 120)
# type:  <class 'PIL.PngImagePlugin.PngImageFile'>
# lr_shape:  (120, 125, 3)
# type:  <class 'numpy.ndarray'>

# %%
sr_img = rdn.predict(lr_img)
#Image.fromarray(sr_img)

# %%
img2 = Image.open('data/input/sample/image1.png')

img2 = img2.convert(mode='RGB')
lr_img2 = np.array(img2)

print('size: ', img2.size)
print('type: ', type(img2))
print('lr_shape: ',lr_img2.shape)
print('type: ', type(lr_img2))
Image.fromarray(lr_img2)
# Out:
# size:  (278, 184)
# type:  <class 'PIL.Image.Image'>
# lr_shape:  (184, 278, 3)
# type:  <class 'numpy.ndarray'>
# <PIL.Image.Image image mode=RGB size=278x184 at 0x131A257B8>

# %%
sr_img = rdn.predict(lr_img2)
result =Image.fromarray(sr_img)
# Out:
# <PIL.Image.Image image mode=RGB size=556x368 at 0x131A25278>

# %%
result =Image.fromarray(sr_img)
result.save('data/input/result/result_img1.png','png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-e60cc622d22a> in <module>
#       1 result =Image.fromarray(sr_img)
# ----> 2 result.save('data/input/result/result_img1.png','png')
#
# ~/anaconda3/envs/iris_2/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2083                 # Open also for reading ("+"), because TIFF save_all
#    2084                 # writer needs to go back and edit the written data.
# -> 2085                 fp = builtins.open(filename, "w+b")
#    2086
#    2087         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/input/result/result_img1.png'
